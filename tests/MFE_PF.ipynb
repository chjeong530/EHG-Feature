# %% [markdown]
# # MPF(Mean Power Frequency)
#
# - PSD(Power Spectrum Density)의 평균 Frequency
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # PF(Peak Frequency)
#
# - power maximum
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # deciles
#
# - 10개로 균등하게 나눔(D1 ~ D9) 으로 나눔.
# ref: Traitement de l’electromyogramme ut ´ erin pour la ´caracterisation des contractions pendant la grossesse(유료 논문)
#
# ![Screenshot%20from%202019-04-30%2014-10-24.png](attachment:Screenshot%20from%202019-04-30%2014-10-24.png)
